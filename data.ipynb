# %%
import neuralnet as nn

# %%
dataset = [[2.7810836,2.550537003,0],
	[1.465489372,2.362125076,0],
	[3.396561688,4.400293529,0],
	[1.38807019,1.850220317,0],
	[3.06407232,3.005305973,0],
	[7.627531214,2.759262235,1],
	[5.332441248,2.088626775,1],
	[6.922596716,1.77106367,1],
	[8.675418651,-0.242068655,1],
	[7.673756466,3.508563011,1]]

n_inputs = len(dataset[0]) - 1
n_outputs = len(set([row[-1] for row in dataset]))

# %%
neural_net = nn.Network()
neural_net.construct_network(n_inputs, [3, n_outputs])
neural_net.train(dataset, 100, n_class=n_outputs, learning_rate=0.2, batch_size=10)
# Out:
# >epoch=0, lrate=0.200, error=6.831
# >epoch=1, lrate=0.200, error=6.038
# >epoch=2, lrate=0.200, error=5.644
# >epoch=3, lrate=0.200, error=5.489
# >epoch=4, lrate=0.200, error=5.429
# >epoch=5, lrate=0.200, error=5.404
# >epoch=6, lrate=0.200, error=5.394
# >epoch=7, lrate=0.200, error=5.389
# >epoch=8, lrate=0.200, error=5.387
# >epoch=9, lrate=0.200, error=5.386
# >epoch=10, lrate=0.200, error=5.385
# >epoch=11, lrate=0.200, error=5.385
# >epoch=12, lrate=0.200, error=5.384
# >epoch=13, lrate=0.200, error=5.384
# >epoch=14, lrate=0.200, error=5.384
# >epoch=15, lrate=0.200, error=5.384
# >epoch=16, lrate=0.200, error=5.383
# >epoch=17, lrate=0.200, error=5.383
# >epoch=18, lrate=0.200, error=5.383
# >epoch=19, lrate=0.200, error=5.383
# >epoch=20, lrate=0.200, error=5.383
# >epoch=21, lrate=0.200, error=5.383
# >epoch=22, lrate=0.200, error=5.383
# >epoch=23, lrate=0.200, error=5.383
# >epoch=24, lrate=0.200, error=5.383
# >epoch=25, lrate=0.200, error=5.383
# >epoch=26, lrate=0.200, error=5.382
# >epoch=27, lrate=0.200, error=5.382
# >epoch=28, lrate=0.200, error=5.382
# >epoch=29, lrate=0.200, error=5.382
# >epoch=30, lrate=0.200, error=5.382
# >epoch=31, lrate=0.200, error=5.382
# >epoch=32, lrate=0.200, error=5.382
# >epoch=33, lrate=0.200, error=5.382
# >epoch=34, lrate=0.200, error=5.382
# >epoch=35, lrate=0.200, error=5.382
# >epoch=36, lrate=0.200, error=5.382
# >epoch=37, lrate=0.200, error=5.382
# >epoch=38, lrate=0.200, error=5.382
# >epoch=39, lrate=0.200, error=5.382
# >epoch=40, lrate=0.200, error=5.382
# >epoch=41, lrate=0.200, error=5.383
# >epoch=42, lrate=0.200, error=5.383
# >epoch=43, lrate=0.200, error=5.383
# >epoch=44, lrate=0.200, error=5.383
# >epoch=45, lrate=0.200, error=5.383
# >epoch=46, lrate=0.200, error=5.383
# >epoch=47, lrate=0.200, error=5.383
# >epoch=48, lrate=0.200, error=5.383
# >epoch=49, lrate=0.200, error=5.383
# >epoch=50, lrate=0.200, error=5.383
# >epoch=51, lrate=0.200, error=5.383
# >epoch=52, lrate=0.200, error=5.383
# >epoch=53, lrate=0.200, error=5.383
# >epoch=54, lrate=0.200, error=5.383
# >epoch=55, lrate=0.200, error=5.383
# >epoch=56, lrate=0.200, error=5.383
# >epoch=57, lrate=0.200, error=5.383
# >epoch=58, lrate=0.200, error=5.383
# >epoch=59, lrate=0.200, error=5.383
# >epoch=60, lrate=0.200, error=5.383
# >epoch=61, lrate=0.200, error=5.383
# >epoch=62, lrate=0.200, error=5.383
# >epoch=63, lrate=0.200, error=5.383
# >epoch=64, lrate=0.200, error=5.383
# >epoch=65, lrate=0.200, error=5.383
# >epoch=66, lrate=0.200, error=5.383
# >epoch=67, lrate=0.200, error=5.383
# >epoch=68, lrate=0.200, error=5.383
# >epoch=69, lrate=0.200, error=5.383
# >epoch=70, lrate=0.200, error=5.383
# >epoch=71, lrate=0.200, error=5.383
# >epoch=72, lrate=0.200, error=5.383
# >epoch=73, lrate=0.200, error=5.383
# >epoch=74, lrate=0.200, error=5.383
# >epoch=75, lrate=0.200, error=5.382
# >epoch=76, lrate=0.200, error=5.382
# >epoch=77, lrate=0.200, error=5.382
# >epoch=78, lrate=0.200, error=5.382
# >epoch=79, lrate=0.200, error=5.382
# >epoch=80, lrate=0.200, error=5.382
# >epoch=81, lrate=0.200, error=5.382
# >epoch=82, lrate=0.200, error=5.382
# >epoch=83, lrate=0.200, error=5.382
# >epoch=84, lrate=0.200, error=5.382
# >epoch=85, lrate=0.200, error=5.382
# >epoch=86, lrate=0.200, error=5.382
# >epoch=87, lrate=0.200, error=5.382
# >epoch=88, lrate=0.200, error=5.382
# >epoch=89, lrate=0.200, error=5.382
# >epoch=90, lrate=0.200, error=5.382
# >epoch=91, lrate=0.200, error=5.382
# >epoch=92, lrate=0.200, error=5.381
# >epoch=93, lrate=0.200, error=5.381
# >epoch=94, lrate=0.200, error=5.381
# >epoch=95, lrate=0.200, error=5.381
# >epoch=96, lrate=0.200, error=5.381
# >epoch=97, lrate=0.200, error=5.381
# >epoch=98, lrate=0.200, error=5.381
# >epoch=99, lrate=0.200, error=5.381
